# %% [markdown]
# GPU编译

# %%
cmake -B build -DGGML_CUDA=ON
cmake --build build --config Release
制定NVCC：
cmake -B build -DCMAKE_BUILD_TYPE=Release -DGGML_CUDA=ON \
  -DCMAKE_CUDA_COMPILER=/usr/local/cuda-12.4/bin/nvcc

# %% [markdown]
# CPU编译

# %%
cmake --build --config Release -j$(nproc)

# %%
./build/bin/llama-cli -m /home/sjtudai/code/gtr/model/Qwen3-8B-BF16.gguf -ngl 25 -n 128

# %%
./build/bin/llama-run -ngl 25 /home/sjtudai/code/gtr/model/Qwen3-8B-BF16.gguf What is 1+2?
